# %%
using System;
using System.Collections.Generic; 

public class Product
{
    private string Name {get; set;}
    private decimal Price {get; set;}
    private int Quantity {get; set;}
    private string Category {get; set;}
    private string Description {get; set;}

    public Product(string name, decimal price, int quantity, string category, string description)
    {
        Name=name;
        Price=price;
        Quantity=quantity;
        Category=category;
        Description=description;
    }

    public decimal GetTotalPrice()
    {
        return Price * Quantity;
    }

    public void UpdateQuantity (int amount)
    {
        Quantity += amount;
    }

    public string GetProductInfo ()
    {
        return $"Продукт: {Name}, Цена: {Price}, Количество: {Quantity}, Категория: {Category}, Описание: {Description}";
    }
}

public class Seller
{
    private string Name {get; set;}
    private string EmployeeID {get; set;}
    protected decimal Salary {get; set;}
    internal string ContactInfo {get; set;}
    
    public Seller (string name, string employeeID, decimal salary, string contactInfo)
    {
        Name = name;
        EmployeeID = employeeID;
        Salary = salary;
        ContactInfo = contactInfo;
    }

    public void AddProduct (string productName, decimal price, int quantity)
    {
        Console.WriteLine($"Добавлен продукт: {productName}, Цена: {price}, Количество: {quantity}");
    }

    public void SellProduct (string productName, int quantity)
    {
        Console.WriteLine ($"Продано {quantity} {productName}s");
    }
    
    public string GetSellerInfo()
    {
        return $"Продавец: {Name}, ID сотрудника: {EmployeeID}, Зарплата: {Salary}, Контактная информация: {ContactInfo}";
    }
}

public class Store
{
    private string storeName;
    private string location;
    public string storeHours;

    
    private List<Seller> sellers = new List<Seller>();

    public Store(string storeName, string location, string storeHours)
    {
        this.storeName = storeName;
        this.location = location;
        this.storeHours = storeHours;
    }

    public void AddSeller(Seller seller)
    {
        sellers.Add(seller);
    }

    public void ListSellers() 
    {
        foreach (var seller in sellers)
        {
            Console.WriteLine(seller.GetSellerInfo());
        }
    }

    public string GetStoreInfo()
    {
        return $"Название магазина: {storeName}, Адрес: {location}, Часы работы: {storeHours}";
    }
}


Product product1 = new Product ("Молоко", 65, 10, "Молочные продкты", "Молоко 2.5%");
Console.WriteLine (product1.GetProductInfo());
product1.UpdateQuantity(5);
Console.WriteLine(product1.GetProductInfo());
decimal totalCost = product1.GetTotalPrice();
Console.WriteLine ($"Конечная цена за молоко: {totalCost}");

Seller seller = new Seller ("Лера", "A8928", 80000, "val148@mail.ru");
Console.WriteLine (seller.GetSellerInfo());

seller.AddProduct ("Хлеб", 35, 10);
seller.SellProduct ("Хлеб", 2);

Store store = new Store ("Ашан", "Тц Кристалл", "9:00-23:00");
Console.WriteLine(store.GetStoreInfo());


store.AddSeller(seller);
store.ListSellers();

Seller seller2 = new Seller("Артём", "A8927", 50000, "art@gmail.com");
Console.WriteLine(seller2.GetSellerInfo());
store.AddSeller(seller2);
Console.WriteLine(store.GetStoreInfo());
store.ListSellers();
# Out:
# Продукт: Молоко, Цена: 65, Количество: 10, Категория: Молочные продкты, Описание: Молоко 2.5%
# Продукт: Молоко, Цена: 65, Количество: 15, Категория: Молочные продкты, Описание: Молоко 2.5%
# Конечная цена за молоко: 975
# Продавец: Лера, ID сотрудника: A8928, Зарплата: 80000, Контактная информация: val148@mail.ru
# Добавлен продукт: Хлеб, Цена: 35, Количество: 10
# Продано 2 Хлебs
# Название магазина: Ашан, Адрес: Тц Кристалл, Часы работы: 9:00-23:00
# Продавец: Лера, ID сотрудника: A8928, Зарплата: 80000, Контактная информация: val148@mail.ru
# Продавец: Артём, ID сотрудника: A8927, Зарплата: 50000, Контактная информация: art@gmail.com
# Название магазина: Ашан, Адрес: Тц Кристалл, Часы работы: 9:00-23:00
# Продавец: Лера, ID сотрудника: A8928, Зарплата: 80000, Контактная информация: val148@mail.ru
# Продавец: Артём, ID сотрудника: A8927, Зарплата: 50000, Контактная информация: art@gmail.com
